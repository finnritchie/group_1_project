# %%
#Group 1 Final Project - (Finn Ritchie, Lewis Duncan, Hannah Cormack, Samantha Gordon)

#function that determine if a string can be converted to an integer (and therefore a float)
def isinteger(value):
    try:
        float(value)
    except ValueError:
        return False
    else:
        return True
    
def GFM():

    def found(le,RAM):
        

        try:
            RAM[le]
        except KeyError:

            return False
        else:

            return True
    
    def lowerc(le):
        if l == le.lower():
            return True
        else:
            return False
    
    def isnull(Uinput):
        try: 
            Uinput[0]
        except IndexError:
            return True
        else:
            return False
        
    RAM = {"H":1.00797, "C":12.011,"N":14.00667,"O":15.9994,"Na":22.98977,"P":30.97376,"S":32.06}
    
    Uinput = input("Please enter the formula of your compound (e.g NaHCO3 (case sensitive)) ")
    valid = False
    
    
    #validation loop(s)
    while isnull(Uinput):
        Uinput = input("Please enter the formula of your compound (e.g NaHCO3 (case sensitive)) ")
    
    
    
    while not valid:
        
        while len(Uinput) == 1 and not valid:
            if not found(Uinput,RAM):
                Uinput = input("Unknown atom found, please re-enter the formula of your compound (e.g NaHCO3 (case sensitive)) (1chr)")
                while isnull(Uinput):
                    Uinput = input("Unknown atom found, please re-enter the formula of your compound (e.g NaHCO3 (case sensitive)) (1chr)")
            else:
                valid = True

        while len(Uinput) != 1 and not valid:
        
            

            counter = 1
            lastletter = Uinput[0]
            for l in Uinput[1:(len(Uinput))]:
                
                
                counter += 1


                l2 = lastletter + l

                if not isinteger(l) and not found(l,RAM):

                    if not found(l2,RAM) and lowerc(l):
       
                        Uinput = input("Unknown atom found, please re-enter the formula of your compound (e.g NaHCO3 (case sensitive)) ")
                        while isnull(Uinput):
                            Uinput = input("Unknown atom found, please re-enter the formula of your compound (e.g NaHCO3 (case sensitive))")
                        valid = False
                        break
                

                if counter == len(Uinput):

                    valid = True
                else:
                    lastletter = l
                    
            break
    #end validation loops 
    
   
    GFM = 0
    counter =0
    AMass = []
    for l in Uinput:

        
        if counter >=4:
            l5 = l4 + l
        if counter >=3:
            l4 = l3 + l
        if counter >= 2:
            l3 = l2 + l
        if counter >=1:
            l2 = Uinput[counter-1] + l
        
        if counter >=1 and found(l2,RAM) and lowerc(l):
            AMass[counter-1]=0
            AMass.append(RAM[l2])
            lastatom = RAM[l2]
        elif isinteger(l):
            if counter >=4 and isinteger(l5):
                for i in range(counter-5,counter):
                    AMass[i]=0
                AMass.append(lastatom *(int(l5)))
            elif counter >=3 and isinteger(l4):
                for i in range(counter-4,counter):
                    AMass[i]=0
                AMass.append(lastatom *(int(l4)))
            elif counter >=2 and isinteger(l3):
                for i in range(counter-3,counter):
                    AMass[i]=0
                AMass.append(lastatom *(int(l3)))
            elif isinteger(l2):
                for i in range(counter-2,counter):
                    AMass[i]=0
                AMass.append(lastatom *(int(l2)))
            else:
                AMass[counter-1] = 0
                AMass.append(lastatom *(int(l)))
        else:
            AMass.append(RAM[l])
            lastatom = RAM[l]
    
        counter += 1
    
    print("The GFM of your molecule is {} g".format(sum(AMass)))
    return sum(AMass)

            
def conc(moles, volume):        
    '''moles: the number of moles of the substance
    volume: The volume of the substance (litre) in float
    result: The concentration of the substance (moles per litre) in float'''
    conc = moles/volume
    return conc

def moles_2(conc, volume):       
    '''conc: The concentration of the substance (moles per litre) in float
    vol: the volume of the substance (litre) in float
    result: The number of moles of the substance in float'''
    n = conc*volume
    return n

def moles_1(gfm, mass):
    '''gfm: gram formula mass of the substance in float
    mass: the mass of the substance (grams) in float
    result: number of moles of the substance in float'''
    n = mass/gfm
    return n

def volume(moles, conc):          
    '''moles: the number of moles of the substance
    conc: The concentration of the substance (moles per litre) in float
    result: The volume of the substance (litres) in float'''
    vol = moles/conc
    return vol

def mass(moles, gfm):  
    '''moles: number of moles of the substance in float
    gfm: the mass of the substance in float
    result: mass of the substance (grams) in float '''
    g = moles*gfm
    return g

def GFM_fromNumbers(moles, mass):
    GFM = moles*mass
    return GFM



#Main Body
valueType = input('What value would you like to calculate? (Choose from concentration(c), number of moles (n), volume(v), mass(m) or GFM(GFM))   '   ) #User to input value to be calculated

while valueType != 'n' and valueType != 'c' and valueType != 'v' and valueType != 'm' and valueType != 'GFM':
    valueType = input('Please enter a valid option (c, n, v, m or GFM). What value would you like to calculate?'   ) #Validation loop - only allows user to input valid options

#Concentration
if valueType == 'c': 
    getInfo1 = input('Please enter the number of moles:  ') 
    while isinteger(getInfo1) == False: #Validation loop - checks if user has entered a numerical value, asks for a new value if not.
        getInfo1 = input('Please enter the number of moles as a numerical value:  ')
    getUnit1 = input('Please enter the unit this value is measured in (e.g. mol, mmol):  ') #Collects unit to use in final unit
    getInfo2 = input('Please enter a volume:  ')
    while isinteger(getInfo2) == False: #Validation loop - checks if user has entered a numerical value, asks for a new value if not.
        getInfo2 = input('Please enter a volume as a numerical value:  ')
    getUnit2 = input('Please enter the unit this value is measured in (e.g. cm^3, L):  ') #Collects unit to use in final unit
    unit = ('{}/{}'.format(getUnit1, getUnit2))
    if getUnit1 == 'mol' and getUnit2 == 'L': #If unit is equivalent to M, gives value in M
        unit = 'M'
    print('The concentration is {:.2f} {}'.format(conc(float(getInfo1), float(getInfo2)), unit)) #Uses concentration function to calculate answer and prints the concentration value via a formatted string.
    
    
#We have used the same method for each type of value below, so please refer to the comments above for expalaination.
    
#Number of moles
elif valueType == 'n':
    valueCombo = input("Which value combination woud you like to use? \nConcentration and volume (enter '1') \nmass and GFM (enter '2') \nMass only (enter '3')")
    
    while valueCombo != '1' and valueCombo != '2' and valueCombo != '3':
        valueCombo = input("Please enter a valid option. \nConcentration and volume (enter '1') \nMass and GFM (enter '2') \nMass only (enter '3')")
    
    if valueCombo == '1':
        getInfo1 = input('Please enter the concentration in mol/L:  ')
        while isinteger(getInfo1) == False: 
            getInfo1 = input('Please enter the concentration as a numerical value:  ')
        getInfo2 = input('Please enter a volume in L:  ')
        while isinteger(getInfo2) == False:
            getInfo2 = input('Please enter the volume as a numerical value:  ')
        print('The number of moles is {:.2f}'.format(moles_2(float(getInfo1), float(getInfo2))))
    
    elif valueCombo == '2':
        getInfo1 = input('Please enter the mass of the substance:  ')
        while isinteger(getInfo1) == False:
            getInfo1 = input('Please enter the mass as a numerical value:  ')
        getInfo2 = input('Please enter the GFM of the substance:  ')
        while isinteger(getInfo2) == False:
            getInfo2 = input('Please enter the GFM as a numerical value:  ')
        print('The number of moles is {:.2f}'.format(moles_1(float(getInfo1), float(getInfo2))))
    
    elif valueCombo == '3':
        getInfo1 = input('Please enter the mass of the substance:  ')
        while isinteger(getInfo1) == False:
            getInfo1 = input('Please enter the mass as a numerical value:  ')
        getInfo2 = GFM()
        print('The number of moles is {:.2f}'.format(moles_1(float(getInfo1), getInfo2)))

#Volume
elif valueType == 'v':
    
    getInfo1 = input('Please enter the number of moles in moles:  ') 
    while isinteger(getInfo1) == False:
            getInfo1 = input('Please enter the number of moles as a numerical value:  ')
    getInfo2 = input('Please enter the concentration in mol/L:  ')
    while isinteger(getInfo2) == False:
            getInfo2 = input('Please enter the concentration as a numerical value:  ')
    print('The volume is {:.2f} L'.format(volume(float(getInfo1), float(getInfo2))))
    

#Mass
elif valueType == 'm':
    which_method = input("Do you know the GFM of the substance? (enter 'y' or 'n')")
    while which_method != 'y' and which_method != 'n':
            which_method = input("Please enter a valid option (enter 'y' for yes, 'n', for no).")
    
    if which_method == 'y':
        getInfo1 = input('Please enter the number of moles in moles:  ')
        while isinteger(getInfo1) == False:
            getInfo1 = input('Please enter the number of moles as a numerical value: ')
        getInfo2 = input('Please enter the GFM:  ')
        while isinteger(getInfo2) == False:
            getInfo2 = input('Please enter the GFM as a numerical value:  ')
    
    elif which_method  == 'n':
        getInfo1 = input('Please enter the number of moles:  ')
        while isinteger(getInfo1) == False:
            getInfo1 = input('Please enter the number of moles as a numerical value: ')
        getInfo2 = GFM()                   
    print('The mass of this substance is {:.2f} g'.format(mass(float(getInfo1), float(getInfo2))))


#GFM
elif valueType == 'GFM':
    which_method = input("How would you like to calculate the GFM? \nEnter 'f' to use the chemical formula or 'num' to use a known mass and number of moles.   ")
    while which_method != 'f' and which_method != 'num':
            which_method = input("Please enter a valid option ('f' or 'num').  ")
    
    if which_method == 'f':
        GFM()
    
    elif which_method == 'num':
        getInfo1 = input('Please enter the number of moles in moles:  ')
        while isinteger(getInfo1) == False:
            getInfo1 = input('Please enter the number of moles as a numerical value: ')
        getInfo2 = input('Please enter the mass in grams:  ')
        while isinteger(getInfo2) == False:
            getInfo2 = input('Please enter the mass as a numerical value:  ')
        print('The GFM of this substance is {:.2f} g'.format(GFM_fromNumbers(float(getInfo1), float(getInfo2))))
